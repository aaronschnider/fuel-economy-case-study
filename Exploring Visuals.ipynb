# %% [markdown]
# # Exploring with Visuals

# %%
# loading the datasets
import pandas as pd

df08 = pd.read_csv('clean_08.csv')
df18 = pd.read_csv('clean_18.csv')

# %%
df08.hist(figsize=(15,15));

# %%
df18.hist(figsize=(15,15));

# %%
df08.plot(x='displ', y='cmb_mpg',kind='scatter');

# %%
df18.plot(x='displ', y='cmb_mpg',kind='scatter');

# %%
df08.plot(x='greenhouse_gas_score', y='cmb_mpg',kind='scatter');

# %%
df18.plot(x='greenhouse_gas_score', y='cmb_mpg',kind='scatter');
